# %%
#Dependencies:
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np
import pprint as pprint
#import ggplot2 as gg

# %%
# Name of the CSV file:
kaggle_file = "../Resources/universities.csv"
insti_file = "../Resources/cc_institution_details.csv"

# %%
#Reading the csv file:
uni_df = pd.read_csv(kaggle_file)

# %%
new_uni_df = uni_df[["displayName",
                    "city",
                    "state",
                    "rankingSortRank",
                    "act_avg",
                    "sat_avg",
                    "acceptance_rate",
                    "engineeringRepScore",
                    "businessRepScore",
                    "tuition"]]
new_uni_df.head()
# Out:
#              displayName       city state  rankingSortRank  act_avg  sat_avg  \
# 0   Princeton University  Princeton    NJ                1     32.0   1400.0
# 1     Harvard University  Cambridge    MA                2     32.0   1430.0
# 2  University of Chicago    Chicago    IL                3     32.0   1450.0
# 3        Yale University  New Haven    CT                3     32.0   1420.0
# 4    Columbia University   New York    NY                5     32.0   1430.0
#
#    acceptance_rate  engineeringRepScore  businessRepScore  tuition
# 0              7.0                  4.1               NaN    47140
# 1              5.0                  3.6               NaN    48949
# 2              8.0                  NaN               NaN    54825
# 3              6.0                  3.4               NaN    51400
# 4              6.0                  3.8               NaN    57208

# %%
#Reading the csv file:
insti_df = pd.read_csv(insti_file, encoding="ISO-8859-1")
insti_df.head()
# Out:
#    unitid                            chronname        city    state   level  \
# 0  100654               Alabama A&M University      Normal  Alabama  4-year
# 1  100663  University of Alabama at Birmingham  Birmingham  Alabama  4-year
# 2  100690                   Amridge University  Montgomery  Alabama  4-year
# 3  100706  University of Alabama at Huntsville  Huntsville  Alabama  4-year
# 4  100724             Alabama State University  Montgomery  Alabama  4-year
#
#                   control                                              basic  \
# 0                  Public  Masters Colleges and Universities--larger prog...
# 1                  Public  Research Universities--very high research acti...
# 2  Private not-for-profit            Baccalaureate Colleges--Arts & Sciences
# 3                  Public  Research Universities--very high research acti...
# 4                  Public  Masters Colleges and Universities--larger prog...
#
#   hbcu flagship     long_x     ...       vsa_grad_after6_transfer  \
# 0    X      NaN -86.568502     ...                           36.4
# 1  NaN      NaN -86.809170     ...                            NaN
# 2  NaN      NaN -86.174010     ...                            NaN
# 3  NaN      NaN -86.638420     ...                            0.0
# 4    X      NaN -86.295677     ...                            NaN
#
#   vsa_grad_elsewhere_after6_transfer  vsa_enroll_after6_transfer  \
# 0                                5.6                        17.2
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                0.0                         0.0
# 4                                NaN                         NaN
#
#    vsa_enroll_elsewhere_after6_transfer  \
# 0                                  11.1
# 1                                   NaN
# 2                                   NaN
# 3                                   0.0
# 4                                   NaN
#
#                                              similar  state_sector_ct  \
# 0  232937|100724|405997|113607|139533|144005|2285...               13
# 1  196060|180461|201885|145600|209542|236939|1268...               13
# 2  217925|441511|205124|247825|197647|221856|1353...               16
# 3  232186|133881|196103|196413|207388|171128|1900...               13
# 4  100654|232937|242617|243197|144005|241739|2354...               13
#
#    carnegie_ct  counted_pct  nicknames  cohort_size
# 0          386      99.7|07        NaN        882.0
# 1          106      56.0|07        UAB       1376.0
# 2          252     100.0|07        NaN          3.0
# 3          106      43.1|07        UAH        759.0
# 4          386      88.0|07        ASU       1351.0
#
# [5 rows x 62 columns]

# %%
new_insti_df = insti_df[["chronname","control","grad_100_value","retain_value"]]

#Finding UNCC in the big dataset:
new_insti_dfuncc=new_insti_df.loc[new_insti_df['chronname']=='University of North Carolina at Charlotte',:]
#new_insti_dfuncc

#drop NaN rows
no_null_cleaner_insti_df = new_insti_df.dropna(how='any')

#drop the institutions with a grad_100_value of 0
no_null_cleaner_insti_no0_grad = no_null_cleaner_insti_df.loc[no_null_cleaner_insti_df['grad_100_value']!=0.0]
#try it
no_null_cleaner_insti_no0_grad.head()

#drop the institutions with a retain_value of 0
no_null_cleaner_insti_no0_grad_no0_retain = no_null_cleaner_insti_no0_grad.loc[no_null_cleaner_insti_no0_grad['retain_value']!=0.0]
#drop the 100s of grad_100
cleaner_insti_no0_grad_no0_retain_no100grad = no_null_cleaner_insti_no0_grad_no0_retain.loc[no_null_cleaner_insti_no0_grad_no0_retain['grad_100_value']!=100]
#drop the 100s of retain_value
cleaner_insti_no0grad_no0_retain_no100grad_no100retain = cleaner_insti_no0_grad_no0_retain_no100grad.loc[cleaner_insti_no0_grad_no0_retain_no100grad['retain_value']!=100]
#make it easier to read
clean_insti = cleaner_insti_no0grad_no0_retain_no100grad_no100retain

#try it out
clean_insti.head()

#Seperate private and public here so I don't need to do the same thing twice.
final_private=clean_insti.loc[clean_insti['control']=='Private not-for-profit']
final_public=clean_insti.loc[clean_insti['control']=='Public']
#no_null_cleaner_private.loc[no_null_cleaner_private['grad_100_value']!=0.0]
#Seperate values into public and private
#no_null_cleaner_public=no_null_cleaner_insti_df.loc[no_null_cleaner_insti_df['control']=='Public']
#no_null_cleaner_private=no_null_cleaner_insti_df.loc[no_null_cleaner_insti_df['control']=='Private not-for-profit']

#Now that it's seperated, I need to pull out the 0's and 100's, both of which I find meaningless.
#no_null_cleaner_private_no0=no_null_cleaner_private.loc[no_null_cleaner_private['grad_100_value']!=0.0]
#no_null_cleaner_private_no0grad_no0retain = no_null_cleaner_private_no0.loc[no_null_cleaner_private_no0['retain_value']!=0.0]
#no_null_cleaner_private_no0grad_no0retain_no100grad = no_null_cleaner_private_no0grad_no0retain.loc[no_null_cleaner_private_no0grad_no0retain['grad_100_value']!=100]
#no_null_cleaner_private_no0grad_no0retain_no100grad_no100retain = no_null_cleaner_private_no0grad_no0retain_no100grad.loc[no_null_cleaner_private_no0grad_no0retain_no100grad['retain_value']!=100]
#final_private = no_null_cleaner_private_no0grad_no0retain_no100grad_no100retain 

#I do the same for my new public value
#no_null_cleaner_public_no0=no_null_cleaner_public.loc[no_null_cleaner_public['grad_100_value']!=0.0]
#no_null_cleaner_public_no0grad_no0retain = no_null_cleaner_public_no0.loc[no_null_cleaner_public_no0['retain_value']!=0.0]
#no_null_cleaner_public_no0grad_no0retain_no100grad = no_null_cleaner_public_no0grad_no0retain.loc[no_null_cleaner_public_no0grad_no0retain['retain_value']!=100]
#no_null_cleaner_public_no0grad_no0retain_no100grad_no100retain = no_null_cleaner_public_no0grad_no0retain_no100grad.loc[no_null_cleaner_public_no0grad_no0retain_no100grad['grad_100_value']!=100]
#final_public = no_null_cleaner_public_no0grad_no0retain_no100grad_no100retain
#final_private.describe()

#I need numbers for the pie chart below
public_total = final_public['chronname'].count()
private_total = final_private['chronname'].count()

#since the private for-profit isn't in here, I'll need to keep total to just private and public
final_total = public_total+private_total
public_40=final_public.head(40)
private_40=final_private.head(40)
final_all=private_40.append(public_40)
final_all['rankingSortRank']=range(1,1+len(final_all))
#since final_all is huuuuuuge, I'm going to limit it to the first 80.
final_80=final_all.head(80)

# %%
#Checking to make sure what I expect to be there is.
final_all
#Maybe I should sort this, based on grad_100_value...
retain_final_all = final_all.sort_values(['grad_100_value'],ascending=False)
last_all=retain_final_all.head(80)
last_all_newf = last_all.rename({"chronname":"displayName"}, axis=1)
last_all_newf.head()
# Out:
#                             displayName                 control  \
# 51                    Talladega College  Private not-for-profit
# 163  California Institute of Technology  Private not-for-profit
# 155       Bethesda Christian University  Private not-for-profit
# 122                     Hendrix College  Private not-for-profit
# 164      California Lutheran University  Private not-for-profit
#
#      grad_100_value  retain_value  rankingSortRank
# 51             82.4          32.9               14
# 163            82.3          96.6               37
# 155            65.2          92.9               33
# 122            63.3          87.8               24
# 164            61.3          84.8               38

# %%
new_insti2 = new_insti_df.rename({"chronname": "displayName"}, axis=1)
new_insti2.head()
new_insti2uncc=new_insti2.loc[new_insti2['displayName']=='University of North Carolina at Charlotte', :]
new_insti2uncc['sequence']=81
#new_insti2uncc.head()
new_insti2uncw=new_insti2.loc[new_insti2['displayName']=='University of North Carolina at Wilmington',:]
new_insti2uncw['sequence']=82
#new_insti2uncw.head()
#new_insti2ucberkley=new_insti2.loc[new_insti2['displayName']=='University of North Carolina at Wilmington',:]
#new_insti2uncw['sequence']=82
#new_insti2uncw.head()
#erge_df['sequence']=range(1,1+len(merge_df))
# Out:
# C:\Users\mulrich\anaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\mulrich\anaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
#Merge two dataframes using an inner join
merge_df = pd.merge(new_uni_df, new_insti2, on = "displayName")
merge_df.head(80)
# Out:
#                               displayName             city state  \
# 0                    Princeton University        Princeton    NJ
# 1                      Harvard University        Cambridge    MA
# 2                   University of Chicago          Chicago    IL
# 3                         Yale University        New Haven    CT
# 4                     Columbia University         New York    NY
# 5   Massachusetts Institute of Technology        Cambridge    MA
# 6                     Stanford University         Stanford    CA
# 7              University of Pennsylvania     Philadelphia    PA
# 8                         Duke University           Durham    NC
# 9      California Institute of Technology         Pasadena    CA
# 10                      Dartmouth College          Hanover    NH
# 11               Johns Hopkins University        Baltimore    MD
# 12                Northwestern University         Evanston    IL
# 13                       Brown University       Providence    RI
# 14                     Cornell University           Ithaca    NY
# 15                        Rice University          Houston    TX
# 16                  Vanderbilt University        Nashville    TN
# 17               University of Notre Dame       Notre Dame    IN
# 18     Washington University in St. Louis        St. Louis    MO
# 19                  Georgetown University       Washington    DC
# 20                       Emory University          Atlanta    GA
# 21      University of Southern California      Los Angeles    CA
# 22             Carnegie Mellon University       Pittsburgh    PA
# 23                 University of Virginia  Charlottesville    VA
# 24                 Wake Forest University    Winston-Salem    NC
# 25                       Tufts University          Medford    MA
# 26                    New York University         New York    NY
# 27                         Boston College    Chestnut Hill    MA
# 28            College of William and Mary     Williamsburg    VA
# 29                    Brandeis University          Waltham    MA
# ..                                    ...              ...   ...
# 50                     Clemson University          Clemson    SC
# 51                    American University       Washington    DC
# 52        Stevens Institute of Technology          Hoboken    NJ
# 53                          Virginia Tech       Blacksburg    VA
# 54                      Baylor University             Waco    TX
# 55               Colorado School of Mines           Golden    CO
# 56             Texas Christian University       Fort Worth    TX
# 57                     University of Iowa        Iowa City    IA
# 58                       Clark University        Worcester    MA
# 59               Florida State University      Tallahassee    FL
# 60              Michigan State University     East Lansing    MI
# 61                 University of Delaware           Newark    DE
# 62                   University of Denver           Denver    CO
# 63                    University of Tulsa            Tulsa    OK
# 64                   Marquette University        Milwaukee    WI
# 65                University of San Diego        San Diego    CA
# 66                      Drexel University     Philadelphia    PA
# 67                 Saint Louis University        St. Louis    MO
# 68                     Yeshiva University         New York    NY
# 69      Rochester Institute of Technology        Rochester    NY
# 70                  University of Vermont       Burlington    VT
# 71                      Auburn University           Auburn    AL
# 72       Illinois Institute of Technology          Chicago    IL
# 73              Loyola University Chicago          Chicago    IL
# 74            University of New Hampshire           Durham    NH
# 75                   University of Oregon           Eugene    OR
# 76                      Howard University       Washington    DC
# 77            University of San Francisco    San Francisco    CA
# 78              University of the Pacific         Stockton    CA
# 79                     University of Utah   Salt Lake City    UT
#
#     rankingSortRank  act_avg  sat_avg  acceptance_rate  engineeringRepScore  \
# 0                 1     32.0   1400.0              7.0                  4.1
# 1                 2     32.0   1430.0              5.0                  3.6
# 2                 3     32.0   1450.0              8.0                  NaN
# 3                 3     32.0   1420.0              6.0                  3.4
# 4                 5     32.0   1430.0              6.0                  3.8
# 5                 5     33.0   1460.0              8.0                  4.9
# 6                 5     31.0   1380.0              5.0                  4.8
# 7                 8     32.0   1380.0              9.0                  3.6
# 8                 9     31.0   1380.0             11.0                  3.7
# 9                10     34.0   1510.0              8.0                  4.6
# 10               11     30.0   1350.0             11.0                  3.2
# 11               11     32.0   1420.0             12.0                  3.9
# 12               11     32.0   1400.0             11.0                  4.0
# 13               14     31.0   1370.0              9.0                  3.3
# 14               14     31.0   1330.0             14.0                  4.2
# 15               14     32.0   1410.0             15.0                  3.7
# 16               14     32.0   1420.0             11.0                  3.4
# 17               18     32.0   1350.0             19.0                  3.3
# 18               18     32.0   1400.0             17.0                  3.3
# 19               20     30.0   1320.0             17.0                  NaN
# 20               21     30.0   1290.0             25.0                  NaN
# 21               21     30.0   1280.0             17.0                  3.6
# 22               25     31.0   1380.0             22.0                  4.3
# 23               25     29.0   1240.0             30.0                  3.4
# 24               27     28.0   1240.0             30.0                  NaN
# 25               29     31.0   1370.0             14.0                  3.0
# 26               30     29.0   1250.0             32.0                  2.9
# 27               32     30.0   1260.0             31.0                  NaN
# 28               32     28.0   1250.0             37.0                  NaN
# 29               34     29.0   1270.0             33.0                  NaN
# ..              ...      ...      ...              ...                  ...
# 50               67     26.0   1150.0             51.0                  3.0
# 51               69     26.0   1150.0             26.0                  NaN
# 52               69     29.0   1260.0             39.0                  2.7
# 53               69      NaN   1100.0             71.0                  3.9
# 54               75     26.0   1120.0             40.0                  2.4
# 55               75     29.0   1250.0             40.0                  3.1
# 56               78     25.0   1070.0             38.0                  2.9
# 57               78     23.0   1020.0             84.0                  2.9
# 58               81     27.0   1110.0             55.0                  NaN
# 59               81     25.0   1110.0             58.0                  NaN
# 60               81     24.0    990.0             66.0                  3.1
# 61               81     23.0   1090.0             65.0                  3.0
# 62               87     26.0   1110.0             53.0                  2.0
# 63               87     26.0   1120.0             37.0                  2.2
# 64               90     24.0   1040.0             74.0                  2.4
# 65               90     26.0   1100.0             51.0                  3.5
# 66               94     25.0   1080.0             75.0                  3.0
# 67               94     24.0   1120.0             65.0                  2.2
# 68               94     23.0   1090.0             51.0                  NaN
# 69               97     26.0   1140.0             55.0                  2.9
# 70               97     25.0   1100.0             69.0                  2.3
# 71              103     24.0   1060.0             81.0                  3.0
# 72              103     26.0   1130.0             57.0                  2.8
# 73              103     24.0   1030.0             73.0                  NaN
# 74              103     22.0    990.0             76.0                  2.3
# 75              103     22.0    980.0             78.0                  NaN
# 76              110     22.0   1040.0             30.0                  2.2
# 77              110     23.0   1030.0             71.0                  NaN
# 78              110     23.0   1030.0             66.0                  2.9
# 79              110     21.0   1050.0             76.0                  2.9
#
#     businessRepScore  tuition                 control  grad_100_value  \
# 0                NaN    47140  Private not-for-profit            87.8
# 1                NaN    48949  Private not-for-profit            86.5
# 2                NaN    54825  Private not-for-profit            87.9
# 3                NaN    51400  Private not-for-profit            89.6
# 4                NaN    57208  Private not-for-profit            85.6
# 5                4.6    49892  Private not-for-profit            83.5
# 6                NaN    49617  Private not-for-profit            76.1
# 7                4.8    53534  Private not-for-profit            87.9
# 8                NaN    53744  Private not-for-profit            87.1
# 9                NaN    49908  Private not-for-profit            82.3
# 10               NaN    52950  Private not-for-profit            86.5
# 11               NaN    52170  Private not-for-profit            86.9
# 12               NaN    52678  Private not-for-profit            86.2
# 13               NaN    53419  Private not-for-profit            84.4
# 14               4.2    52853  Private not-for-profit            86.6
# 15               NaN    45608  Private not-for-profit            78.8
# 16               NaN    47664  Private not-for-profit            86.7
# 17               4.1    51505  Private not-for-profit            89.8
# 18               4.0    51533  Private not-for-profit            88.2
# 19               3.8    52300  Private not-for-profit            88.0
# 20               3.8    49392  Private not-for-profit            83.8
# 21               4.1    54259  Private not-for-profit            78.2
# 22               4.2    53910  Private not-for-profit            74.3
# 23               4.2    46975                  Public            86.3
# 24               3.4    51400  Private not-for-profit            81.8
# 25               NaN    54318  Private not-for-profit            87.2
# 26               4.3    50464  Private not-for-profit            77.3
# 27               3.6    53346  Private not-for-profit            88.5
# 28               3.3    43099                  Public            83.1
# 29               2.9    53582  Private not-for-profit            86.2
# ..               ...      ...                     ...             ...
# 50               3.0    35654                  Public            59.1
# 51               2.9    46615  Private not-for-profit            75.9
# 52               2.5    50554  Private not-for-profit            44.5
# 53               3.2    29371                  Public            60.6
# 54               3.1    43790  Private not-for-profit            57.2
# 55               NaN    37436                  Public            41.2
# 56               3.0    44760  Private not-for-profit            58.6
# 57               3.5    28813                  Public            47.5
# 58               2.5    44400  Private not-for-profit            75.5
# 59               3.2    21673                  Public            56.6
# 60               3.6    39405                  Public            50.4
# 61               3.0    32250                  Public            68.4
# 62               2.9    48669  Private not-for-profit            66.5
# 63               2.5    39502  Private not-for-profit            51.5
# 64               2.9    39900  Private not-for-profit            57.3
# 65               2.8    47708  Private not-for-profit            64.6
# 66               2.8    52002  Private not-for-profit            28.3
# 67               2.9    42166  Private not-for-profit            60.7
# 68               2.3    42000  Private not-for-profit            60.0
# 69               3.1    40068  Private not-for-profit            28.4
# 70               2.6    41356                  Public            64.8
# 71               3.1    29640                  Public            37.6
# 72               2.3    45864  Private not-for-profit            31.5
# 73               3.0    42828  Private not-for-profit            59.7
# 74               2.6    32637                  Public            63.7
# 75               3.1    34611                  Public            43.6
# 76               2.7    25697  Private not-for-profit            39.6
# 77               2.8    46250  Private not-for-profit            56.6
# 78               2.2    46346  Private not-for-profit            39.8
# 79               3.2    26408                  Public            24.0
#
#     retain_value
# 0           97.6
# 1           97.1
# 2           99.3
# 3           98.7
# 4           97.3
# 5           97.9
# 6           98.6
# 7           97.8
# 8           97.2
# 9           96.6
# 10          97.9
# 11          97.0
# 12          97.7
# 13          97.1
# 14          96.8
# 15          98.2
# 16          97.3
# 17          98.6
# 18          96.4
# 19          96.0
# 20          94.4
# 21          96.0
# 22          94.2
# 23          97.0
# 24          92.9
# 25          96.4
# 26          92.5
# 27          94.8
# 28          95.6
# 29          93.0
# ..           ...
# 50          91.9
# 51          88.2
# 52          96.3
# 53          91.2
# 54          88.2
# 55          91.9
# 56          90.2
# 57          85.8
# 58          88.6
# 59          91.7
# 60          90.5
# 61          91.9
# 62          86.8
# 63          90.3
# 64          90.7
# 65          90.2
# 66          86.4
# 67          86.8
# 68          92.9
# 69          86.9
# 70          85.8
# 71          89.5
# 72          86.0
# 73          85.4
# 74          86.4
# 75          86.7
# 76          81.5
# 77          86.5
# 78          86.6
# 79          87.9
#
# [80 rows x 13 columns]

# %%
#merge_df['sequence']=range(1,1+len(merge_df))
#Merge two more on outer join
merge_final=pd.merge(merge_df,last_all_newf, on = "grad_100_value", how="outer")
merge_last_table=merge_final.head(80)
#this dataset is different. interesting. University of Pennsylvania is higher, and I don't know why.
merge_last_table
# Out:
#                             displayName_x             city state  \
# 0                    Princeton University        Princeton    NJ
# 1                      Harvard University        Cambridge    MA
# 2                       Dartmouth College          Hanover    NH
# 3                   University of Chicago          Chicago    IL
# 4              University of Pennsylvania     Philadelphia    PA
# 5                         Yale University        New Haven    CT
# 6                     Columbia University         New York    NY
# 7   Massachusetts Institute of Technology        Cambridge    MA
# 8                     Stanford University         Stanford    CA
# 9                         Duke University           Durham    NC
# 10     California Institute of Technology         Pasadena    CA
# 11               Johns Hopkins University        Baltimore    MD
# 12                Northwestern University         Evanston    IL
# 13                    Brandeis University          Waltham    MA
# 14                   Villanova University        Villanova    PA
# 15                       Brown University       Providence    RI
# 16                     Cornell University           Ithaca    NY
# 17                        Rice University          Houston    TX
# 18                  Vanderbilt University        Nashville    TN
# 19               University of Notre Dame       Notre Dame    IN
# 20     Washington University in St. Louis        St. Louis    MO
# 21                  Georgetown University       Washington    DC
# 22                       Emory University          Atlanta    GA
# 23      University of Southern California      Los Angeles    CA
# 24             Carnegie Mellon University       Pittsburgh    PA
# 25                 University of Virginia  Charlottesville    VA
# 26                 Wake Forest University    Winston-Salem    NC
# 27                       Tufts University          Medford    MA
# 28                    New York University         New York    NY
# 29                         Boston College    Chestnut Hill    MA
# ..                                    ...              ...   ...
# 50                    Syracuse University         Syracuse    NY
# 51        Worcester Polytechnic Institute        Worcester    MA
# 52                     Clemson University          Clemson    SC
# 53                    American University       Washington    DC
# 54        Stevens Institute of Technology          Hoboken    NJ
# 55                          Virginia Tech       Blacksburg    VA
# 56                      Baylor University             Waco    TX
# 57               Colorado School of Mines           Golden    CO
# 58             Texas Christian University       Fort Worth    TX
# 59                     University of Iowa        Iowa City    IA
# 60                       Clark University        Worcester    MA
# 61               Florida State University      Tallahassee    FL
# 62            University of San Francisco    San Francisco    CA
# 63              Michigan State University     East Lansing    MI
# 64                 University of Delaware           Newark    DE
# 65                   University of Denver           Denver    CO
# 66                    University of Tulsa            Tulsa    OK
# 67                   Marquette University        Milwaukee    WI
# 68                University of San Diego        San Diego    CA
# 69                      Drexel University     Philadelphia    PA
# 70                 Saint Louis University        St. Louis    MO
# 71                     Yeshiva University         New York    NY
# 72      Rochester Institute of Technology        Rochester    NY
# 73                      Auburn University           Auburn    AL
# 74       Illinois Institute of Technology          Chicago    IL
# 75              Loyola University Chicago          Chicago    IL
# 76            University of New Hampshire           Durham    NH
# 77                   University of Oregon           Eugene    OR
# 78                      Howard University       Washington    DC
# 79              University of the Pacific         Stockton    CA
#
#     rankingSortRank_x  act_avg  sat_avg  acceptance_rate  engineeringRepScore  \
# 0                 1.0     32.0   1400.0              7.0                  4.1
# 1                 2.0     32.0   1430.0              5.0                  3.6
# 2                11.0     30.0   1350.0             11.0                  3.2
# 3                 3.0     32.0   1450.0              8.0                  NaN
# 4                 8.0     32.0   1380.0              9.0                  3.6
# 5                 3.0     32.0   1420.0              6.0                  3.4
# 6                 5.0     32.0   1430.0              6.0                  3.8
# 7                 5.0     33.0   1460.0              8.0                  4.9
# 8                 5.0     31.0   1380.0              5.0                  4.8
# 9                 9.0     31.0   1380.0             11.0                  3.7
# 10               10.0     34.0   1510.0              8.0                  4.6
# 11               11.0     32.0   1420.0             12.0                  3.9
# 12               11.0     32.0   1400.0             11.0                  4.0
# 13               34.0     29.0   1270.0             33.0                  NaN
# 14               46.0     30.0   1220.0             44.0                  2.5
# 15               14.0     31.0   1370.0              9.0                  3.3
# 16               14.0     31.0   1330.0             14.0                  4.2
# 17               14.0     32.0   1410.0             15.0                  3.7
# 18               14.0     32.0   1420.0             11.0                  3.4
# 19               18.0     32.0   1350.0             19.0                  3.3
# 20               18.0     32.0   1400.0             17.0                  3.3
# 21               20.0     30.0   1320.0             17.0                  NaN
# 22               21.0     30.0   1290.0             25.0                  NaN
# 23               21.0     30.0   1280.0             17.0                  3.6
# 24               25.0     31.0   1380.0             22.0                  4.3
# 25               25.0     29.0   1240.0             30.0                  3.4
# 26               27.0     28.0   1240.0             30.0                  NaN
# 27               29.0     31.0   1370.0             14.0                  3.0
# 28               30.0     29.0   1250.0             32.0                  2.9
# 29               32.0     30.0   1260.0             31.0                  NaN
# ..                ...      ...      ...              ...                  ...
# 50               61.0     25.0   1090.0             52.0                  2.6
# 51               61.0     28.0   1200.0             48.0                  2.9
# 52               67.0     26.0   1150.0             51.0                  3.0
# 53               69.0     26.0   1150.0             26.0                  NaN
# 54               69.0     29.0   1260.0             39.0                  2.7
# 55               69.0      NaN   1100.0             71.0                  3.9
# 56               75.0     26.0   1120.0             40.0                  2.4
# 57               75.0     29.0   1250.0             40.0                  3.1
# 58               78.0     25.0   1070.0             38.0                  2.9
# 59               78.0     23.0   1020.0             84.0                  2.9
# 60               81.0     27.0   1110.0             55.0                  NaN
# 61               81.0     25.0   1110.0             58.0                  NaN
# 62              110.0     23.0   1030.0             71.0                  NaN
# 63               81.0     24.0    990.0             66.0                  3.1
# 64               81.0     23.0   1090.0             65.0                  3.0
# 65               87.0     26.0   1110.0             53.0                  2.0
# 66               87.0     26.0   1120.0             37.0                  2.2
# 67               90.0     24.0   1040.0             74.0                  2.4
# 68               90.0     26.0   1100.0             51.0                  3.5
# 69               94.0     25.0   1080.0             75.0                  3.0
# 70               94.0     24.0   1120.0             65.0                  2.2
# 71               94.0     23.0   1090.0             51.0                  NaN
# 72               97.0     26.0   1140.0             55.0                  2.9
# 73              103.0     24.0   1060.0             81.0                  3.0
# 74              103.0     26.0   1130.0             57.0                  2.8
# 75              103.0     24.0   1030.0             73.0                  NaN
# 76              103.0     22.0    990.0             76.0                  2.3
# 77              103.0     22.0    980.0             78.0                  NaN
# 78              110.0     22.0   1040.0             30.0                  2.2
# 79              110.0     23.0   1030.0             66.0                  2.9
#
#     businessRepScore  tuition               control_x  grad_100_value  \
# 0                NaN  47140.0  Private not-for-profit            87.8
# 1                NaN  48949.0  Private not-for-profit            86.5
# 2                NaN  52950.0  Private not-for-profit            86.5
# 3                NaN  54825.0  Private not-for-profit            87.9
# 4                4.8  53534.0  Private not-for-profit            87.9
# 5                NaN  51400.0  Private not-for-profit            89.6
# 6                NaN  57208.0  Private not-for-profit            85.6
# 7                4.6  49892.0  Private not-for-profit            83.5
# 8                NaN  49617.0  Private not-for-profit            76.1
# 9                NaN  53744.0  Private not-for-profit            87.1
# 10               NaN  49908.0  Private not-for-profit            82.3
# 11               NaN  52170.0  Private not-for-profit            86.9
# 12               NaN  52678.0  Private not-for-profit            86.2
# 13               2.9  53582.0  Private not-for-profit            86.2
# 14               3.2  51434.0  Private not-for-profit            86.2
# 15               NaN  53419.0  Private not-for-profit            84.4
# 16               4.2  52853.0  Private not-for-profit            86.6
# 17               NaN  45608.0  Private not-for-profit            78.8
# 18               NaN  47664.0  Private not-for-profit            86.7
# 19               4.1  51505.0  Private not-for-profit            89.8
# 20               4.0  51533.0  Private not-for-profit            88.2
# 21               3.8  52300.0  Private not-for-profit            88.0
# 22               3.8  49392.0  Private not-for-profit            83.8
# 23               4.1  54259.0  Private not-for-profit            78.2
# 24               4.2  53910.0  Private not-for-profit            74.3
# 25               4.2  46975.0                  Public            86.3
# 26               3.4  51400.0  Private not-for-profit            81.8
# 27               NaN  54318.0  Private not-for-profit            87.2
# 28               4.3  50464.0  Private not-for-profit            77.3
# 29               3.6  53346.0  Private not-for-profit            88.5
# ..               ...      ...                     ...             ...
# 50               3.3  46755.0  Private not-for-profit            68.5
# 51               2.6  48628.0  Private not-for-profit            70.2
# 52               3.0  35654.0                  Public            59.1
# 53               2.9  46615.0  Private not-for-profit            75.9
# 54               2.5  50554.0  Private not-for-profit            44.5
# 55               3.2  29371.0                  Public            60.6
# 56               3.1  43790.0  Private not-for-profit            57.2
# 57               NaN  37436.0                  Public            41.2
# 58               3.0  44760.0  Private not-for-profit            58.6
# 59               3.5  28813.0                  Public            47.5
# 60               2.5  44400.0  Private not-for-profit            75.5
# 61               3.2  21673.0                  Public            56.6
# 62               2.8  46250.0  Private not-for-profit            56.6
# 63               3.6  39405.0                  Public            50.4
# 64               3.0  32250.0                  Public            68.4
# 65               2.9  48669.0  Private not-for-profit            66.5
# 66               2.5  39502.0  Private not-for-profit            51.5
# 67               2.9  39900.0  Private not-for-profit            57.3
# 68               2.8  47708.0  Private not-for-profit            64.6
# 69               2.8  52002.0  Private not-for-profit            28.3
# 70               2.9  42166.0  Private not-for-profit            60.7
# 71               2.3  42000.0  Private not-for-profit            60.0
# 72               3.1  40068.0  Private not-for-profit            28.4
# 73               3.1  29640.0                  Public            37.6
# 74               2.3  45864.0  Private not-for-profit            31.5
# 75               3.0  42828.0  Private not-for-profit            59.7
# 76               2.6  32637.0                  Public            63.7
# 77               3.1  34611.0                  Public            43.6
# 78               2.7  25697.0  Private not-for-profit            39.6
# 79               2.2  46346.0  Private not-for-profit            39.8
#
#     retain_value_x                       displayName_y  \
# 0             97.6                                 NaN
# 1             97.1                                 NaN
# 2             97.9                                 NaN
# 3             99.3                                 NaN
# 4             97.8                                 NaN
# 5             98.7                                 NaN
# 6             97.3                                 NaN
# 7             97.9                                 NaN
# 8             98.6                                 NaN
# 9             97.2                                 NaN
# 10            96.6  California Institute of Technology
# 11            97.0                                 NaN
# 12            97.7                                 NaN
# 13            93.0                                 NaN
# 14            94.0                                 NaN
# 15            97.1                                 NaN
# 16            96.8                                 NaN
# 17            98.2                                 NaN
# 18            97.3                                 NaN
# 19            98.6                                 NaN
# 20            96.4                                 NaN
# 21            96.0                                 NaN
# 22            94.4                                 NaN
# 23            96.0                                 NaN
# 24            94.2                                 NaN
# 25            97.0                                 NaN
# 26            92.9                                 NaN
# 27            96.4                                 NaN
# 28            92.5                                 NaN
# 29            94.8                                 NaN
# ..             ...                                 ...
# 50            91.9                                 NaN
# 51            95.9                                 NaN
# 52            91.9                                 NaN
# 53            88.2                                 NaN
# 54            96.3                                 NaN
# 55            91.2                                 NaN
# 56            88.2                                 NaN
# 57            91.9                                 NaN
# 58            90.2                                 NaN
# 59            85.8                                 NaN
# 60            88.6                                 NaN
# 61            91.7                                 NaN
# 62            86.5                                 NaN
# 63            90.5                                 NaN
# 64            91.9                                 NaN
# 65            86.8                                 NaN
# 66            90.3    California Institute of the Arts
# 67            90.7                                 NaN
# 68            90.2                                 NaN
# 69            86.4                                 NaN
# 70            86.8                                 NaN
# 71            92.9                                 NaN
# 72            86.9                                 NaN
# 73            89.5                   Auburn University
# 74            86.0                                 NaN
# 75            85.4                                 NaN
# 76            86.4                                 NaN
# 77            86.7                                 NaN
# 78            81.5                                 NaN
# 79            86.6                                 NaN
#
#                  control_y  retain_value_y  rankingSortRank_y
# 0                      NaN             NaN                NaN
# 1                      NaN             NaN                NaN
# 2                      NaN             NaN                NaN
# 3                      NaN             NaN                NaN
# 4                      NaN             NaN                NaN
# 5                      NaN             NaN                NaN
# 6                      NaN             NaN                NaN
# 7                      NaN             NaN                NaN
# 8                      NaN             NaN                NaN
# 9                      NaN             NaN                NaN
# 10  Private not-for-profit            96.6               37.0
# 11                     NaN             NaN                NaN
# 12                     NaN             NaN                NaN
# 13                     NaN             NaN                NaN
# 14                     NaN             NaN                NaN
# 15                     NaN             NaN                NaN
# 16                     NaN             NaN                NaN
# 17                     NaN             NaN                NaN
# 18                     NaN             NaN                NaN
# 19                     NaN             NaN                NaN
# 20                     NaN             NaN                NaN
# 21                     NaN             NaN                NaN
# 22                     NaN             NaN                NaN
# 23                     NaN             NaN                NaN
# 24                     NaN             NaN                NaN
# 25                     NaN             NaN                NaN
# 26                     NaN             NaN                NaN
# 27                     NaN             NaN                NaN
# 28                     NaN             NaN                NaN
# 29                     NaN             NaN                NaN
# ..                     ...             ...                ...
# 50                     NaN             NaN                NaN
# 51                     NaN             NaN                NaN
# 52                     NaN             NaN                NaN
# 53                     NaN             NaN                NaN
# 54                     NaN             NaN                NaN
# 55                     NaN             NaN                NaN
# 56                     NaN             NaN                NaN
# 57                     NaN             NaN                NaN
# 58                     NaN             NaN                NaN
# 59                     NaN             NaN                NaN
# 60                     NaN             NaN                NaN
# 61                     NaN             NaN                NaN
# 62                     NaN             NaN                NaN
# 63                     NaN             NaN                NaN
# 64                     NaN             NaN                NaN
# 65                     NaN             NaN                NaN
# 66  Private not-for-profit            85.0               40.0
# 67                     NaN             NaN                NaN
# 68                     NaN             NaN                NaN
# 69                     NaN             NaN                NaN
# 70                     NaN             NaN                NaN
# 71                     NaN             NaN                NaN
# 72                     NaN             NaN                NaN
# 73                  Public            89.5               48.0
# 74                     NaN             NaN                NaN
# 75                     NaN             NaN                NaN
# 76                     NaN             NaN                NaN
# 77                     NaN             NaN                NaN
# 78                     NaN             NaN                NaN
# 79                     NaN             NaN                NaN
#
# [80 rows x 17 columns]

# %%
#new_insti2.set_index('retain_value')
#new_insti2.head()
#new_insti3=new_insti2.loc[(new_insti2.loc['retain_value']!=100)]
#new_insti3

# %%
merge_df["act_avg"] = merge_df["act_avg"].replace("NaN", np.nan).fillna(0)
merge_df["sat_avg"] = merge_df["sat_avg"].replace("NaN", np.nan).fillna(0)
merge_df["acceptance_rate"] = merge_df["acceptance_rate"].replace("NaN", np.nan).fillna(0)
merge_df["retain_value"] = merge_df["retain_value"].replace("NaN", np.nan).fillna(0)
merge_df["grad_100_value"] = merge_df["grad_100_value"].replace("NaN", np.nan).fillna(0)
merge_df["engineeringRepScore"] = merge_df["engineeringRepScore"].replace("NaN", np.nan).fillna(0)
merge_df["businessRepScore"] = merge_df["businessRepScore"].replace("NaN", np.nan).fillna(0)

# %%
merge_last_table["act_avg"] = merge_last_table["act_avg"].replace("NaN", np.nan).fillna(0)
merge_last_table["sat_avg"] = merge_last_table["sat_avg"].replace("NaN", np.nan).fillna(0)
merge_last_table["acceptance_rate"] = merge_last_table["acceptance_rate"].replace("NaN", np.nan).fillna(0)
merge_last_table["engineeringRepScore"] = merge_last_table["engineeringRepScore"].replace("NaN", np.nan).fillna(0)
merge_last_table["businessRepScore"] = merge_last_table["businessRepScore"].replace("NaN", np.nan).fillna(0)
# Out:
# C:\Users\mulrich\anaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mulrich\anaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\mulrich\anaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\mulrich\anaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\mulrich\anaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
merge_table = merge_df.head(80)
merge_test = merge_table.head()
last_table = merge_last_table.head()
#ucberkley=new_insti2.loc[new_insti2['displayName']=='Harvard University',:]
#ucberkley.head()
merge_test.head()
merge_test2=merge_test.append(new_insti2uncc, sort=False)
merge_test4=merge_test.append(new_insti2uncw, sort=False)
merge_test5=merge_test.append(last_table, sort=False)
merge_test3=merge_test2.sort_values('control')
merge_test3=pd.merge(merge_test, new_insti2uncc, on = 'grad_100_value')
merge_table2=merge_table.append(new_insti2uncc, sort=False)
merge_table2['sequence']=range(1,1+len(merge_table2))
merge_table2
merge_table3=merge_table2.append(new_insti2uncw, sort=False)
merge_table3
merge_test5
# Out:
#              displayName          city state  rankingSortRank  act_avg  \
# 0   Princeton University     Princeton    NJ              1.0     32.0
# 1     Harvard University     Cambridge    MA              2.0     32.0
# 2  University of Chicago       Chicago    IL              3.0     32.0
# 3        Yale University     New Haven    CT              3.0     32.0
# 4    Columbia University      New York    NY              5.0     32.0
# 0                    NaN     Princeton    NJ              NaN     32.0
# 1                    NaN     Cambridge    MA              NaN     32.0
# 2                    NaN       Hanover    NH              NaN     30.0
# 3                    NaN       Chicago    IL              NaN     32.0
# 4                    NaN  Philadelphia    PA              NaN     32.0
#
#    sat_avg  acceptance_rate  engineeringRepScore  businessRepScore  tuition  \
# 0   1400.0              7.0                  4.1               0.0  47140.0
# 1   1430.0              5.0                  3.6               0.0  48949.0
# 2   1450.0              8.0                  0.0               0.0  54825.0
# 3   1420.0              6.0                  3.4               0.0  51400.0
# 4   1430.0              6.0                  3.8               0.0  57208.0
# 0   1400.0              7.0                  4.1               0.0  47140.0
# 1   1430.0              5.0                  3.6               0.0  48949.0
# 2   1350.0             11.0                  3.2               0.0  52950.0
# 3   1450.0              8.0                  0.0               0.0  54825.0
# 4   1380.0              9.0                  3.6               4.8  53534.0
#
#          ...         grad_100_value  retain_value               displayName_x  \
# 0        ...                   87.8          97.6                         NaN
# 1        ...                   86.5          97.1                         NaN
# 2        ...                   87.9          99.3                         NaN
# 3        ...                   89.6          98.7                         NaN
# 4        ...                   85.6          97.3                         NaN
# 0        ...                   87.8           NaN        Princeton University
# 1        ...                   86.5           NaN          Harvard University
# 2        ...                   86.5           NaN           Dartmouth College
# 3        ...                   87.9           NaN       University of Chicago
# 4        ...                   87.9           NaN  University of Pennsylvania
#
#   rankingSortRank_x               control_x retain_value_x  displayName_y  \
# 0               NaN                     NaN            NaN            NaN
# 1               NaN                     NaN            NaN            NaN
# 2               NaN                     NaN            NaN            NaN
# 3               NaN                     NaN            NaN            NaN
# 4               NaN                     NaN            NaN            NaN
# 0               1.0  Private not-for-profit           97.6            NaN
# 1               2.0  Private not-for-profit           97.1            NaN
# 2              11.0  Private not-for-profit           97.9            NaN
# 3               3.0  Private not-for-profit           99.3            NaN
# 4               8.0  Private not-for-profit           97.8            NaN
#
#   control_y retain_value_y  rankingSortRank_y
# 0       NaN            NaN                NaN
# 1       NaN            NaN                NaN
# 2       NaN            NaN                NaN
# 3       NaN            NaN                NaN
# 4       NaN            NaN                NaN
# 0       NaN            NaN                NaN
# 1       NaN            NaN                NaN
# 2       NaN            NaN                NaN
# 3       NaN            NaN                NaN
# 4       NaN            NaN                NaN
#
# [10 rows x 21 columns]

# %%
#Determine public or private
#private_universities_df = merge_last_table.loc[merge_last_table["control_y"] == "Private not-for-profit", :]
#private_profit_universities_df = merge_last_table.loc[merge_last_table["control"] == "Private for-profit", :]
#private_universities_df.describe()
#public_universities_df = merge_last_table.loc[merge_last_table["control_y"] == "Public", :]
#public_universities_df.head()
#display_name = merge_last_table['displayName']
#pub_display_name = public_universities_df['displayName']
#pri_display_name = private_universities_df['displayName']
#grouped_university = merge_table.groupby('control')
#final_merge= pd.merge()

# %%
# Determine counts for pie chart
#since I'm looking at the full set here, I want to keep all values, and not limit it to just the 80, as that will give
#me a 50/50
all_private_count = final_private['chronname'].count()
all_public_count = final_public['chronname'].count()
all_total_count = last_all['chronname'].count()
#Determine sizes for pie chart
all_public_percent = (all_public_count)/(all_total_count)
all_private_percent = (all_private_count)/(all_total_count)
# Build Pie Chart
labels = 'Public','Private not-for-profit'
sizes = [all_public_percent, all_private_percent]
colors="Red","Gold"
explode = [0,0.1]
plt.pie(sizes, labels=labels,colors=colors,explode=explode,autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis('equal')
plt.title('Count of Private-not-for-profit vs Public for bigger data frame')
# Show Figure
plt.show()
plt.savefig('privatepublicall.png')

# %%
# Determine axes for the public and private Business score
mean_public_business_score = public_universities_df['businessRepScore'].mean()
mean_public_engineering_score = public_universities_df['engineeringRepScore'].mean()
mean_private_business_score = private_universities_df['businessRepScore'].mean()
mean_private_engineering_score = private_universities_df['engineeringRepScore'].mean()
x_axispub = 'Public'
x_axispri ='Private'

# %%
plt.figure(figsize=(3,8))
pubbusbar = plt.bar(x_axispub, mean_public_business_score, color='Red', align="edge")
pribusbar = plt.bar(x_axispri, mean_private_business_score, color='Gold', align="edge")
plt.title("Mean Business Scores of Public and Private Institutions")
plt.ylabel("Mean Business Score")
plt.show()

# %%
plt.figure(figsize=(3,8))
pub_eng_bar = plt.bar(x_axispub, mean_public_engineering_score, color='Red', align="edge")
pri_eng_bar = plt.bar(x_axispri, mean_private_engineering_score, color='Gold', align="edge")
plt.title("Mean Engineering Scores of Public and Private Institutions")
plt.ylabel("Mean Engineering Score")
plt.show()

# %%
sizes=grouped_university
colors=('b','r')

# %%
#Determine sizes for pie chart
public_count = public_universities_df['displayName'].count()
public_count
private_count = private_universities_df['displayName'].count()
total_count = merge_table3['displayName'].count()
public_percent = (public_count)/(total_count)
private_percent = (private_count)/(total_count)
# Build Pie Chart
labels = 'Public','Private'
sizes = [public_percent, private_percent]
colors="Red","Gold"
explode = [0,0.1]
plt.pie(sizes, labels=labels,colors=colors,explode=explode,autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis('equal')
plt.title('Count of Private vs Public')
# Show Figure
plt.show()
plt.savefig('publicprivatepie.png')

# %%
# Determine counts for pie chart
#since I'm looking at the full set here, I want to keep all values, and not limit it to just the 80, as that will give
#me a 50/50
all_private_count = final_private['chronname'].count()
all_public_count = final_public['chronname'].count()
all_total_count = last_all['chronname'].count()
#Determine sizes for pie chart
all_public_percent = (all_public_count)/(all_total_count)
all_private_percent = (all_private_count)/(all_total_count)
# Build Pie Chart
labels = 'Public','Private'
sizes = [all_public_percent, all_private_percent]
colors="Red","Gold"
explode = [0,0.1]
plt.pie(sizes, labels=labels,colors=colors,explode=explode,autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis('equal')
plt.title('Count of Private vs Public for bigger data frame')
# Show Figure
plt.show()
plt.savefig('privatpublicall.png')
#Since this is only the count of each, the ratio is interesting to me, but there's little else I can do with it.

# %%
public_tuition = public_universities_df['tuition'].sum()
private_tuition = private_universities_df['tuition'].sum()
total_tuition = public_tuition+private_tuition
print(total_tuition)
print(public_tuition)
print(private_tuition)
#print(private_count+public_count)
# Out:
# 3643579.0
# 643878.0
# 2999701.0

# %%
#Determine sizes for pie chart
public_count = public_universities_df['displayName'].count()
private_count = private_universities_df['displayName'].count()
total_count = merge_table['displayName'].count()
publictuition_percent = (public_tuition)/(total_tuition)
privatetuition_percent = (private_tuition)/(total_tuition)
# Build Pie Chart
labels = 'Public','Private'
sizes = [publictuition_percent, privatetuition_percent]
colors="Red","Gold"
explode=[0,0.1]
plt.pie(sizes, labels=labels,explode=explode,colors=colors,autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis('equal')
plt.title('Tuition of Public vs Private')
# Show Figure
plt.show()

# %%
#merge_table2['displayName'].count()
totalcount=merge_table['sequence']
total_grad=merge_table['grad_100_value']
total_retain=merge_table['retain_value']
totalcount_2= merge_table['sequence']
#gradavg2=merge_table2['grad_100_value']
#retain2=merge_table2['retain_value']
total_count2=last_all['sequence']
grad_2=last_all['grad_100_value']
retain_2=last_all['retain_value']
#s=merge_table2['sequence'=='81']
#scatter_total_uncc = plt.scatter(total_count2,retain_2,s=100,facecolor='Red',edgecolor='Black')
scatter_total_all=plt.scatter(total_count2,retain_2,facecolor='Red',edgecolor='Black')
#plt.text[81,80,s="uncc"]
scatter_total=plt.scatter(totalcount,total_retain,facecolor='Gold',edgecolor='Black')
plt.title("Retention by University Index")
plt.xlabel("University Index")
plt.ylabel("Retention")
plt.show()
plt.savefig('nonsenseretention.png')
#This, as I predicted, is nonsense. Though the ratio is interesting, the actual data is for all intents and purposes, meaningless.

# %%
totalcount=merge_table['sequence']
total_grad=merge_table['grad_100_value']
total_retain=merge_table['retain_value']
totalcount_3= merge_table3['sequence']
#gradavg2=merge_table2['grad_100_value']
#retain2=merge_table2['retain_value']
total_count3=new_insti2uncw['sequence']
grad_3=new_insti2uncw['grad_100_value']
retain_3=new_insti2uncw['retain_value']
#s=merge_table2['sequence'=='81']
scatter_total_uncw = plt.scatter(total_count3,retain_3,s=100,facecolor='Red',edgecolor='Black')
#plt.text[81,80,s="uncc"]
scatter_total=plt.scatter(totalcount,total_retain,facecolor='Gold',edgecolor='Black')
plt.title("Retention by University Index -including UNCW")
plt.xlabel("University Index")
plt.ylabel("Retention")
plt.text(3,14, s='UNCW in red', fontdict=None, withdash=False)
plt.show()
plt.savefig('retentionuncw.png')

# %%
total_count_uncc=new_insti2uncc['sequence']
grad_uncc=new_insti2uncc['grad_100_value']
retain_uncc=new_insti2uncc['retain_value']
scatter_total_grad_uncc = plt.scatter(total_count_uncc,grad_uncc,s=100,facecolor='Red',edgecolor='Black')
#plt.text[81,80,s="uncc"]
scatter_total_grad=plt.scatter(totalcount,total_retain,facecolor='Gold',edgecolor='Black')
plt.title("Graduation Rate by University Index")
plt.xlabel("University Index")
plt.ylabel("Graduation Rate")
plt.show()
plt.savefig("graduationrateuncc.png")

# %%
scatter_total_grad_uncw = plt.scatter(total_count3,grad_3,s=100,facecolor='Red',edgecolor='Black')
#plt.text[81,80,s="uncc"]
scatter_total_grad=plt.scatter(totalcount,total_retain,facecolor='Gold',edgecolor='Black')
plt.title("Graduation Rate by University Index")
plt.xlabel("University Index")
plt.ylabel("Graduation Rate")
plt.show()
