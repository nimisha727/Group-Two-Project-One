# %%
#Dependencies:
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import pprint as pprint

# %%
# Name of the CSV file:
kaggle_file = "../Resources/universities.csv"
insti_file = "../Resources/cc_institution_details.csv"

# %%
#Reading the csv file:
uni_df = pd.read_csv(kaggle_file)
uni_df.head()
# Out:
#    Unnamed: 0  rankingNoteText nonResponderText  nonResponder  act_avg  \
# 0           1              NaN              NaN         False     32.0
# 1           2              NaN              NaN         False     32.0
# 2           3              NaN              NaN         False     32.0
# 3           4              NaN              NaN         False     32.0
# 4           5              NaN              NaN         False     32.0
#
#                                         primaryPhoto  \
# 0  https://www.usnews.com/img/college-photo_31291...
# 1  https://www.usnews.com/img/college-photo_8866.jpg
# 2  https://www.usnews.com/dims4/USNEWS/5b128f0/17...
# 3  https://www.usnews.com/dims4/USNEWS/60348dd/17...
# 4  https://www.usnews.com/img/college-photo_19002...
#
#                                    primaryPhotoThumb  sat_avg  enrollment  \
# 0  https://www.usnews.com/img/college-photo_31291...   1400.0      5400.0
# 1  https://www.usnews.com/img/college-photo_8866_...   1430.0      6710.0
# 2  https://www.usnews.com/dims4/USNEWS/196469f/17...   1450.0      5941.0
# 3  https://www.usnews.com/dims4/USNEWS/1ca230f/17...   1420.0      5472.0
# 4  https://www.usnews.com/img/college-photo_19002...   1430.0      6113.0
#
#         city    ...                 schoolType  region  aliasNames  \
# 0  Princeton    ...      national-universities     NaN         NaN
# 1  Cambridge    ...      national-universities     NaN         NaN
# 2    Chicago    ...      national-universities     NaN    UChicago
# 3  New Haven    ...      national-universities     NaN         NaN
# 4   New York    ...      national-universities     NaN         NaN
#
#              rankingType  overallRank  institutionalControl  \
# 0  national-universities            1               private
# 1  national-universities            2               private
# 2  national-universities            3               private
# 3  national-universities            3               private
# 4  national-universities            5               private
#
#    rankingMaxPossibleScore rankingRankStatus  primaryKey  univ_rank
# 0                      NaN            ranked        2627        1.0
# 1                      NaN            ranked        2155        2.0
# 2                      NaN            ranked        1774        3.0
# 3                      NaN            ranked        1426        3.0
# 4                      NaN            ranked        2707        5.0
#
# [5 rows x 41 columns]

# %%
new_uni_df = uni_df[["displayName",
                    "city",
                    "state",
                     "zip",
                    "rankingSortRank",
                    "act_avg",
                    "sat_avg",
                    "acceptance_rate",
                    "engineeringRepScore",
                    "businessRepScore",
                    "tuition"]]
new_uni_df.head()
# Out:
#              displayName       city state    zip  rankingSortRank  act_avg  \
# 0   Princeton University  Princeton    NJ   8544                1     32.0
# 1     Harvard University  Cambridge    MA   2138                2     32.0
# 2  University of Chicago    Chicago    IL  60637                3     32.0
# 3        Yale University  New Haven    CT   6520                3     32.0
# 4    Columbia University   New York    NY  10027                5     32.0
#
#    sat_avg  acceptance_rate  engineeringRepScore  businessRepScore  tuition
# 0   1400.0              7.0                  4.1               NaN    47140
# 1   1430.0              5.0                  3.6               NaN    48949
# 2   1450.0              8.0                  NaN               NaN    54825
# 3   1420.0              6.0                  3.4               NaN    51400
# 4   1430.0              6.0                  3.8               NaN    57208

# %%
#Reading the csv file:
insti_df = pd.read_csv(insti_file, encoding="ISO-8859-1")
insti_df.head()
# Out:
#    unitid                            chronname        city    state   level  \
# 0  100654               Alabama A&M University      Normal  Alabama  4-year
# 1  100663  University of Alabama at Birmingham  Birmingham  Alabama  4-year
# 2  100690                   Amridge University  Montgomery  Alabama  4-year
# 3  100706  University of Alabama at Huntsville  Huntsville  Alabama  4-year
# 4  100724             Alabama State University  Montgomery  Alabama  4-year
#
#                   control                                              basic  \
# 0                  Public  Masters Colleges and Universities--larger prog...
# 1                  Public  Research Universities--very high research acti...
# 2  Private not-for-profit            Baccalaureate Colleges--Arts & Sciences
# 3                  Public  Research Universities--very high research acti...
# 4                  Public  Masters Colleges and Universities--larger prog...
#
#   hbcu flagship     long_x     ...       vsa_grad_after6_transfer  \
# 0    X      NaN -86.568502     ...                           36.4
# 1  NaN      NaN -86.809170     ...                            NaN
# 2  NaN      NaN -86.174010     ...                            NaN
# 3  NaN      NaN -86.638420     ...                            0.0
# 4    X      NaN -86.295677     ...                            NaN
#
#   vsa_grad_elsewhere_after6_transfer  vsa_enroll_after6_transfer  \
# 0                                5.6                        17.2
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                0.0                         0.0
# 4                                NaN                         NaN
#
#    vsa_enroll_elsewhere_after6_transfer  \
# 0                                  11.1
# 1                                   NaN
# 2                                   NaN
# 3                                   0.0
# 4                                   NaN
#
#                                              similar  state_sector_ct  \
# 0  232937|100724|405997|113607|139533|144005|2285...               13
# 1  196060|180461|201885|145600|209542|236939|1268...               13
# 2  217925|441511|205124|247825|197647|221856|1353...               16
# 3  232186|133881|196103|196413|207388|171128|1900...               13
# 4  100654|232937|242617|243197|144005|241739|2354...               13
#
#    carnegie_ct  counted_pct  nicknames  cohort_size
# 0          386      99.7|07        NaN        882.0
# 1          106      56.0|07        UAB       1376.0
# 2          252     100.0|07        NaN          3.0
# 3          106      43.1|07        UAH        759.0
# 4          386      88.0|07        ASU       1351.0
#
# [5 rows x 62 columns]

# %%
new_insti_df = insti_df[["chronname","control","grad_100_value","retain_value"]]
new_insti_df.head()
# Out:
#                              chronname                 control  \
# 0               Alabama A&M University                  Public
# 1  University of Alabama at Birmingham                  Public
# 2                   Amridge University  Private not-for-profit
# 3  University of Alabama at Huntsville                  Public
# 4             Alabama State University                  Public
#
#    grad_100_value  retain_value
# 0            10.0          63.1
# 1            29.4          80.2
# 2             0.0          37.5
# 3            16.5          81.0
# 4             8.8          62.2

# %%
new_insti2 = new_insti_df.rename({"chronname": "displayName"}, axis=1)
new_insti2.head()
# Out:
#                            displayName                 control  \
# 0               Alabama A&M University                  Public
# 1  University of Alabama at Birmingham                  Public
# 2                   Amridge University  Private not-for-profit
# 3  University of Alabama at Huntsville                  Public
# 4             Alabama State University                  Public
#
#    grad_100_value  retain_value
# 0            10.0          63.1
# 1            29.4          80.2
# 2             0.0          37.5
# 3            16.5          81.0
# 4             8.8          62.2

# %%
#Merge two dataframes using an inner join
merge_df = pd.merge(new_uni_df, new_insti2, on = "displayName")

# %%
merge_df.head()
# Out:
#              displayName       city state    zip  rankingSortRank  act_avg  \
# 0   Princeton University  Princeton    NJ   8544                1     32.0
# 1     Harvard University  Cambridge    MA   2138                2     32.0
# 2  University of Chicago    Chicago    IL  60637                3     32.0
# 3        Yale University  New Haven    CT   6520                3     32.0
# 4    Columbia University   New York    NY  10027                5     32.0
#
#    sat_avg  acceptance_rate  engineeringRepScore  businessRepScore  tuition  \
# 0   1400.0              7.0                  4.1               NaN    47140
# 1   1430.0              5.0                  3.6               NaN    48949
# 2   1450.0              8.0                  NaN               NaN    54825
# 3   1420.0              6.0                  3.4               NaN    51400
# 4   1430.0              6.0                  3.8               NaN    57208
#
#                   control  grad_100_value  retain_value
# 0  Private not-for-profit            87.8          97.6
# 1  Private not-for-profit            86.5          97.1
# 2  Private not-for-profit            87.9          99.3
# 3  Private not-for-profit            89.6          98.7
# 4  Private not-for-profit            85.6          97.3

# %%
merge_df["act_avg"] = merge_df["act_avg"].replace("NaN", np.nan).fillna(0)
merge_df["sat_avg"] = merge_df["sat_avg"].replace("NaN", np.nan).fillna(0)
merge_df["acceptance_rate"] = merge_df["acceptance_rate"].replace("NaN", np.nan).fillna(0)
merge_df["retain_value"] = merge_df["retain_value"].replace("NaN", np.nan).fillna(0)
merge_df["grad_100_value"] = merge_df["grad_100_value"].replace("NaN", np.nan).fillna(0)
merge_df["engineeringRepScore"] = merge_df["engineeringRepScore"].replace("NaN", np.nan).fillna(0)
merge_df["businessRepScore"] = merge_df["businessRepScore"].replace("NaN", np.nan).fillna(0)

# %%
merge_table = merge_df.head(80)
merge_table
# Out:
#                               displayName             city state    zip  \
# 0                    Princeton University        Princeton    NJ   8544
# 1                      Harvard University        Cambridge    MA   2138
# 2                   University of Chicago          Chicago    IL  60637
# 3                         Yale University        New Haven    CT   6520
# 4                     Columbia University         New York    NY  10027
# 5   Massachusetts Institute of Technology        Cambridge    MA   2139
# 6                     Stanford University         Stanford    CA  94305
# 7              University of Pennsylvania     Philadelphia    PA  19104
# 8                         Duke University           Durham    NC  27708
# 9      California Institute of Technology         Pasadena    CA  91125
# 10                      Dartmouth College          Hanover    NH   3755
# 11               Johns Hopkins University        Baltimore    MD  21218
# 12                Northwestern University         Evanston    IL  60208
# 13                       Brown University       Providence    RI   2912
# 14                     Cornell University           Ithaca    NY  14853
# 15                        Rice University          Houston    TX  77251
# 16                  Vanderbilt University        Nashville    TN  37240
# 17               University of Notre Dame       Notre Dame    IN  46556
# 18     Washington University in St. Louis        St. Louis    MO  63130
# 19                  Georgetown University       Washington    DC  20057
# 20                       Emory University          Atlanta    GA  30322
# 21      University of Southern California      Los Angeles    CA  90089
# 22             Carnegie Mellon University       Pittsburgh    PA  15213
# 23                 University of Virginia  Charlottesville    VA  22904
# 24                 Wake Forest University    Winston-Salem    NC  27109
# 25                       Tufts University          Medford    MA   2155
# 26                    New York University         New York    NY  10012
# 27                         Boston College    Chestnut Hill    MA   2467
# 28            College of William and Mary     Williamsburg    VA  23187
# 29                    Brandeis University          Waltham    MA   2454
# ..                                    ...              ...   ...    ...
# 50                     Clemson University          Clemson    SC  29634
# 51                    American University       Washington    DC  20016
# 52        Stevens Institute of Technology          Hoboken    NJ   7030
# 53                          Virginia Tech       Blacksburg    VA  24061
# 54                      Baylor University             Waco    TX  76798
# 55               Colorado School of Mines           Golden    CO  80401
# 56             Texas Christian University       Fort Worth    TX  76129
# 57                     University of Iowa        Iowa City    IA  52242
# 58                       Clark University        Worcester    MA   1610
# 59               Florida State University      Tallahassee    FL  32306
# 60              Michigan State University     East Lansing    MI  48824
# 61                 University of Delaware           Newark    DE  19716
# 62                   University of Denver           Denver    CO  80208
# 63                    University of Tulsa            Tulsa    OK  74104
# 64                   Marquette University        Milwaukee    WI  53201
# 65                University of San Diego        San Diego    CA  92110
# 66                      Drexel University     Philadelphia    PA  19104
# 67                 Saint Louis University        St. Louis    MO  63103
# 68                     Yeshiva University         New York    NY  10033
# 69      Rochester Institute of Technology        Rochester    NY  14623
# 70                  University of Vermont       Burlington    VT   5405
# 71                      Auburn University           Auburn    AL  36849
# 72       Illinois Institute of Technology          Chicago    IL  60616
# 73              Loyola University Chicago          Chicago    IL  60660
# 74            University of New Hampshire           Durham    NH   3824
# 75                   University of Oregon           Eugene    OR  97403
# 76                      Howard University       Washington    DC  20059
# 77            University of San Francisco    San Francisco    CA  94117
# 78              University of the Pacific         Stockton    CA  95211
# 79                     University of Utah   Salt Lake City    UT  84112
#
#     rankingSortRank  act_avg  sat_avg  acceptance_rate  engineeringRepScore  \
# 0                 1     32.0   1400.0              7.0                  4.1
# 1                 2     32.0   1430.0              5.0                  3.6
# 2                 3     32.0   1450.0              8.0                  0.0
# 3                 3     32.0   1420.0              6.0                  3.4
# 4                 5     32.0   1430.0              6.0                  3.8
# 5                 5     33.0   1460.0              8.0                  4.9
# 6                 5     31.0   1380.0              5.0                  4.8
# 7                 8     32.0   1380.0              9.0                  3.6
# 8                 9     31.0   1380.0             11.0                  3.7
# 9                10     34.0   1510.0              8.0                  4.6
# 10               11     30.0   1350.0             11.0                  3.2
# 11               11     32.0   1420.0             12.0                  3.9
# 12               11     32.0   1400.0             11.0                  4.0
# 13               14     31.0   1370.0              9.0                  3.3
# 14               14     31.0   1330.0             14.0                  4.2
# 15               14     32.0   1410.0             15.0                  3.7
# 16               14     32.0   1420.0             11.0                  3.4
# 17               18     32.0   1350.0             19.0                  3.3
# 18               18     32.0   1400.0             17.0                  3.3
# 19               20     30.0   1320.0             17.0                  0.0
# 20               21     30.0   1290.0             25.0                  0.0
# 21               21     30.0   1280.0             17.0                  3.6
# 22               25     31.0   1380.0             22.0                  4.3
# 23               25     29.0   1240.0             30.0                  3.4
# 24               27     28.0   1240.0             30.0                  0.0
# 25               29     31.0   1370.0             14.0                  3.0
# 26               30     29.0   1250.0             32.0                  2.9
# 27               32     30.0   1260.0             31.0                  0.0
# 28               32     28.0   1250.0             37.0                  0.0
# 29               34     29.0   1270.0             33.0                  0.0
# ..              ...      ...      ...              ...                  ...
# 50               67     26.0   1150.0             51.0                  3.0
# 51               69     26.0   1150.0             26.0                  0.0
# 52               69     29.0   1260.0             39.0                  2.7
# 53               69      0.0   1100.0             71.0                  3.9
# 54               75     26.0   1120.0             40.0                  2.4
# 55               75     29.0   1250.0             40.0                  3.1
# 56               78     25.0   1070.0             38.0                  2.9
# 57               78     23.0   1020.0             84.0                  2.9
# 58               81     27.0   1110.0             55.0                  0.0
# 59               81     25.0   1110.0             58.0                  0.0
# 60               81     24.0    990.0             66.0                  3.1
# 61               81     23.0   1090.0             65.0                  3.0
# 62               87     26.0   1110.0             53.0                  2.0
# 63               87     26.0   1120.0             37.0                  2.2
# 64               90     24.0   1040.0             74.0                  2.4
# 65               90     26.0   1100.0             51.0                  3.5
# 66               94     25.0   1080.0             75.0                  3.0
# 67               94     24.0   1120.0             65.0                  2.2
# 68               94     23.0   1090.0             51.0                  0.0
# 69               97     26.0   1140.0             55.0                  2.9
# 70               97     25.0   1100.0             69.0                  2.3
# 71              103     24.0   1060.0             81.0                  3.0
# 72              103     26.0   1130.0             57.0                  2.8
# 73              103     24.0   1030.0             73.0                  0.0
# 74              103     22.0    990.0             76.0                  2.3
# 75              103     22.0    980.0             78.0                  0.0
# 76              110     22.0   1040.0             30.0                  2.2
# 77              110     23.0   1030.0             71.0                  0.0
# 78              110     23.0   1030.0             66.0                  2.9
# 79              110     21.0   1050.0             76.0                  2.9
#
#     businessRepScore  tuition                 control  grad_100_value  \
# 0                0.0    47140  Private not-for-profit            87.8
# 1                0.0    48949  Private not-for-profit            86.5
# 2                0.0    54825  Private not-for-profit            87.9
# 3                0.0    51400  Private not-for-profit            89.6
# 4                0.0    57208  Private not-for-profit            85.6
# 5                4.6    49892  Private not-for-profit            83.5
# 6                0.0    49617  Private not-for-profit            76.1
# 7                4.8    53534  Private not-for-profit            87.9
# 8                0.0    53744  Private not-for-profit            87.1
# 9                0.0    49908  Private not-for-profit            82.3
# 10               0.0    52950  Private not-for-profit            86.5
# 11               0.0    52170  Private not-for-profit            86.9
# 12               0.0    52678  Private not-for-profit            86.2
# 13               0.0    53419  Private not-for-profit            84.4
# 14               4.2    52853  Private not-for-profit            86.6
# 15               0.0    45608  Private not-for-profit            78.8
# 16               0.0    47664  Private not-for-profit            86.7
# 17               4.1    51505  Private not-for-profit            89.8
# 18               4.0    51533  Private not-for-profit            88.2
# 19               3.8    52300  Private not-for-profit            88.0
# 20               3.8    49392  Private not-for-profit            83.8
# 21               4.1    54259  Private not-for-profit            78.2
# 22               4.2    53910  Private not-for-profit            74.3
# 23               4.2    46975                  Public            86.3
# 24               3.4    51400  Private not-for-profit            81.8
# 25               0.0    54318  Private not-for-profit            87.2
# 26               4.3    50464  Private not-for-profit            77.3
# 27               3.6    53346  Private not-for-profit            88.5
# 28               3.3    43099                  Public            83.1
# 29               2.9    53582  Private not-for-profit            86.2
# ..               ...      ...                     ...             ...
# 50               3.0    35654                  Public            59.1
# 51               2.9    46615  Private not-for-profit            75.9
# 52               2.5    50554  Private not-for-profit            44.5
# 53               3.2    29371                  Public            60.6
# 54               3.1    43790  Private not-for-profit            57.2
# 55               0.0    37436                  Public            41.2
# 56               3.0    44760  Private not-for-profit            58.6
# 57               3.5    28813                  Public            47.5
# 58               2.5    44400  Private not-for-profit            75.5
# 59               3.2    21673                  Public            56.6
# 60               3.6    39405                  Public            50.4
# 61               3.0    32250                  Public            68.4
# 62               2.9    48669  Private not-for-profit            66.5
# 63               2.5    39502  Private not-for-profit            51.5
# 64               2.9    39900  Private not-for-profit            57.3
# 65               2.8    47708  Private not-for-profit            64.6
# 66               2.8    52002  Private not-for-profit            28.3
# 67               2.9    42166  Private not-for-profit            60.7
# 68               2.3    42000  Private not-for-profit            60.0
# 69               3.1    40068  Private not-for-profit            28.4
# 70               2.6    41356                  Public            64.8
# 71               3.1    29640                  Public            37.6
# 72               2.3    45864  Private not-for-profit            31.5
# 73               3.0    42828  Private not-for-profit            59.7
# 74               2.6    32637                  Public            63.7
# 75               3.1    34611                  Public            43.6
# 76               2.7    25697  Private not-for-profit            39.6
# 77               2.8    46250  Private not-for-profit            56.6
# 78               2.2    46346  Private not-for-profit            39.8
# 79               3.2    26408                  Public            24.0
#
#     retain_value
# 0           97.6
# 1           97.1
# 2           99.3
# 3           98.7
# 4           97.3
# 5           97.9
# 6           98.6
# 7           97.8
# 8           97.2
# 9           96.6
# 10          97.9
# 11          97.0
# 12          97.7
# 13          97.1
# 14          96.8
# 15          98.2
# 16          97.3
# 17          98.6
# 18          96.4
# 19          96.0
# 20          94.4
# 21          96.0
# 22          94.2
# 23          97.0
# 24          92.9
# 25          96.4
# 26          92.5
# 27          94.8
# 28          95.6
# 29          93.0
# ..           ...
# 50          91.9
# 51          88.2
# 52          96.3
# 53          91.2
# 54          88.2
# 55          91.9
# 56          90.2
# 57          85.8
# 58          88.6
# 59          91.7
# 60          90.5
# 61          91.9
# 62          86.8
# 63          90.3
# 64          90.7
# 65          90.2
# 66          86.4
# 67          86.8
# 68          92.9
# 69          86.9
# 70          85.8
# 71          89.5
# 72          86.0
# 73          85.4
# 74          86.4
# 75          86.7
# 76          81.5
# 77          86.5
# 78          86.6
# 79          87.9
#
# [80 rows x 14 columns]

# %%
sat_act = merge_tabel[["sequence","sat_avg","act_avg"]]

# %%
y1 = sat_act["sat_avg"]
y2 = sat_act["act_avg"]
x = sat_act["sequence"]

# %%
trace1 = []
